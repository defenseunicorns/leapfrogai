# %%
import openai
# Put anything you want in `API key`
openai.api_key = 'Free the models'

# Point to leapfrogai
openai.api_base = "https://leapfrogai.leapfrogai.bigbang.dev"
from langchain.embeddings import OpenAIEmbeddings

embeddings = OpenAIEmbeddings(openai_api_key="foobar",
                              openai_api_base="https://leapfrogai.leapfrogai.bigbang.dev",
                              model="text-embedding-ada-002")

print(print(openai.Model.list()))
# Out:
# {
#   "data": [
#     {
#       "description": "C++ implementation of LlaMA model, 7B parameters, 4-bit quantization",
#       "id": "llama-7B-4b",
#       "owned_by": "Defense Unicorns",
#       "permission": []
#     },
#     {
#       "description": "C++ implementation of LlaMA model, 7B parameters, 4-bit quantization",
#       "id": "text-embedding-ada-002",
#       "owned_by": "Defense Unicorns",
#       "permission": []
#     }
#   ],
#   "object": "list"
# }
# None

# %%
from langchain.vectorstores import Weaviate
import weaviate
            
client = weaviate.Client(url="https://weaviate.leapfrogai.bigbang.dev",
                         additional_headers={
        'X-OpenAI-Api-Key': "foobar"
    })
client.schema.get()
client.get_meta()

schema = {
    "classes": [
        {
            "class": "Paragraph",
            "description": "A written paragraph",
            "vectorizer": "text2vec-transformers",
              "moduleConfig": {
                "text2vec-openai": {
                  "model": "ada",
                  "modelVersion": "002",
                  "type": "text"
                }
              },
            "properties": [
                {
                    "dataType": ["text"],
                    "description": "The content of the paragraph",
                    "moduleConfig": {
                        "text2vec-transformers": {
                          "skip": False,
                          "vectorizePropertyName": False
                        }
                      },
                    "name": "content",
                },
                {
                    "dataType": ["text"],
                    "description": "The source of the paragraph",
                    "moduleConfig": {
                        "text2vec-transformers": {
                          "skip": False,
                          "vectorizePropertyName": False
                        }
                      },
                    "name": "source",
                },
            ],
        },
    ]
}

client.schema.create(schema)
# Out:
# ---------------------------------------------------------------------------
# UnexpectedStatusCodeException             Traceback (most recent call last)
# Cell In[23], line 52
#       9 client.get_meta()
#      11 schema = {
#      12     "classes": [
#      13         {
#    (...)
#      49     ]
#      50 }
# ---> 52 client.schema.create(schema)
#
# File ~/.local/lib/python3.10/site-packages/weaviate/schema/crud_schema.py:130, in Schema.create(self, schema)
#     128 # validate the schema before loading
#     129 validate_schema(loaded_schema)
# --> 130 self._create_classes_with_primitives(loaded_schema["classes"])
#     131 self._create_complex_properties_from_classes(loaded_schema["classes"])
#
# File ~/.local/lib/python3.10/site-packages/weaviate/schema/crud_schema.py:765, in Schema._create_classes_with_primitives(self, schema_classes_list)
#     753 """
#     754 Create all the classes in the list and primitive properties.
#     755 This function does not create references,
#    (...)
#     761     A list of classes as they are found in a schema JSON description.
#     762 """
#     764 for weaviate_class in schema_classes_list:
# --> 765     self._create_class_with_primitives(weaviate_class)
#
# File ~/.local/lib/python3.10/site-packages/weaviate/schema/crud_schema.py:750, in Schema._create_class_with_primitives(self, weaviate_class)
#     748     raise RequestsConnectionError("Class may not have been created properly.") from conn_err
#     749 if response.status_code != 200:
# --> 750     raise UnexpectedStatusCodeException("Create class", response)
#
# UnexpectedStatusCodeException: Create class! Unexpected status code: 422, with response body: {'error': [{'message': 'class name "Paragraph" already exists'}]}.

# %%
vectordb = Weaviate(client, "Paragraph", "content", embedding=embeddings)

# %%
from langchain.document_loaders import UnstructuredMarkdownLoader, UnstructuredPDFLoader, UnstructuredHTMLLoader, UnstructuredFileLoader
from langchain.document_loaders import PyPDFLoader, CSVLoader, Docx2txtLoader, UnstructuredPowerPointLoader
from typing import List
from langchain.docstore.document import Document

from langchain.text_splitter import CharacterTextSplitter

# from langchain.document_loaders import SlackDirectoryLoader
# google workspace?

# %%
# client.schema.delete_all()

# %%
import os

def load_file(file_path) -> List[Document]:
    _, file_extension = os.path.splitext(file_path)
    data: List[Document]
    if file_extension.lower() == '.html':
        loader = UnstructuredHTMLLoader(file_path)
        return loader.load()
    elif file_extension.lower() == '.pdf':
        loader = PyPDFLoader(file_path)
        return loader.load()
    elif file_extension.lower() == '.md':
        loader = UnstructuredMarkdownLoader(file_path)
        return loader.load()
    elif file_extension.lower() == '.csv':
        loader = CSVLoader(file_path)
        return loader.load()
    elif file_extension.lower() == '.pptx':
        loader = UnstructuredPowerPointLoader(file_path)
        return loader.load()
    elif file_extension.lower() == '.docx':
        loader = Docx2txtLoader(file_path)
        return loader.load()
    else:
        # Perform action for other files or skip
        print(f"Skipping unsupported file: {file_path}")
        return UnstructuredFileLoader(file_path).load()

def process_file(file_path, chunk_size=400, chunk_overlap=200):
    text_splitter = CharacterTextSplitter(chunk_size=chunk_size, chunk_overlap=chunk_overlap)
    try:
        data = load_file(file_path=file_path)
        texts = text_splitter.split_documents(data)
        
        contents = [d.page_content for d in texts]
        metadatas = [d.metadata for d in texts] 
        vectordb.add_texts(
            texts=contents,
            metadatas=metadatas,
        )
         # split and load into weaviate
        print(f"Found { len(data) } parts in file { file_path}")
    except Exception as e: 
        print(f"process_file: Error parsing file { file_path}.  { e }")
        
   

def process_directory(folder_path):
    for root, _, files in os.walk(folder_path):
        for file in files:
            file_path = os.path.join(root, file)
            try:
                process_file(file_path)
            except Exception as e:
                print(f"process_directory: Error processing file { file_path}: { e }")

# %%
process_file("../data/github/defenseunicorns/zarf/CONTRIBUTING.md")
# data = load_file("../data/csrc.nist.gov/csrc/media/projects/block-cipher-techniques/documents/bcm/proposed-modes/ffx/ffx-voltage-ip.pdf")
# Out:
# Found 1 parts in file ../data/github/defenseunicorns/zarf/CONTRIBUTING.md

# %%
process_directory("../data/")
# Out:
# <frozen importlib._bootstrap>:914: ImportWarning: _SixMetaPathImporter.find_spec() not found; falling back to find_module()
# Created a chunk of size 836, which is longer than the specified 400
# Created a chunk of size 601, which is longer than the specified 400
# Created a chunk of size 1437, which is longer than the specified 400
# Created a chunk of size 422, which is longer than the specified 400
# Skipping unsupported file: ../data/seed.txt
# process_file: Error parsing file ../data/seed.txt.  Skipping
# Skipping unsupported file: ../data/github.txt
# process_file: Error parsing file ../data/github.txt.  Skipping
# Skipping unsupported file: ../data/scrape.sh
# process_file: Error parsing file ../data/scrape.sh.  Skipping
# Skipping unsupported file: ../data/googledrive
# process_file: Error parsing file ../data/googledrive.  Skipping
# Skipping unsupported file: ../data/csrc.nist.gov/search?ipp=25&sortBy=relevance&showOnly=presentations&topicsMatch=ANY&topics=27701|maintenance
# process_file: Error parsing file ../data/csrc.nist.gov/search?ipp=25&sortBy=relevance&showOnly=presentations&topicsMatch=ANY&topics=27701|maintenance.  Skipping
# Skipping unsupported file: ../data/csrc.nist.gov/events?sortBy-lg=StartDateTime+DESC&ipp-lg=25&topics-lg=27461|enterprise&topicsMatch-lg=ANY
# process_file: Error parsing file ../data/csrc.nist.gov/events?sortBy-lg=StartDateTime+DESC&ipp-lg=25&topics-lg=27461|enterprise&topicsMatch-lg=ANY.  Skipping
# Skipping unsupported file: ../data/csrc.nist.gov/projects?sortBy-lg=Name+ASC&ipp-lg=25&topics-lg=27495|cloud+&+virtualization&topicsMatch-lg=ANY
# process_file: Error parsing file ../data/csrc.nist.gov/projects?sortBy-lg=Name+ASC&ipp-lg=25&topics-lg=27495|cloud+&+virtualization&topicsMatch-lg=ANY.  Skipping
# Skipping unsupported file: ../data/csrc.nist.gov/events?sortBy-lg=StartDateTime+DESC&ipp-lg=25&topics-lg=27500|networks&topicsMatch-lg=ANY
# process_file: Error parsing file ../data/csrc.nist.gov/events?sortBy-lg=StartDateTime+DESC&ipp-lg=25&topics-lg=27500|networks&topicsMatch-lg=ANY.  Skipping
# Skipping unsupported file: ../data/csrc.nist.gov/search?ipp=25&sortBy=relevance&showOnly=presentations&topicsMatch=ANY&topics=27713|trustworthiness
# process_file: Error parsing file ../data/csrc.nist.gov/search?ipp=25&sortBy=relevance&showOnly=presentations&topicsMatch=ANY&topics=27713|trustworthiness.  Skipping
# Skipping unsupported file: ../data/csrc.nist.gov/events?sortBy-lg=StartDateTime+DESC&ipp-lg=25&topics-lg=27704|personnel+security&topicsMatch-lg=ANY
# process_file: Error parsing file ../data/csrc.nist.gov/events?sortBy-lg=StartDateTime+DESC&ipp-lg=25&topics-lg=27704|personnel+security&topicsMatch-lg=ANY.  Skipping
# Skipping unsupported file: ../data/csrc.nist.gov/search?ipp=25&sortBy=relevance&showOnly=presentations&topicsMatch=ANY&topics=27664|access+control
# process_file: Error parsing file ../data/csrc.nist.gov/search?ipp=25&sortBy=relevance&showOnly=presentations&topicsMatch=ANY&topics=27664|access+control.  Skipping
# Skipping unsupported file: ../data/csrc.nist.gov/news?sortBy-lg=NewsDateTime+DESC&ipp-lg=25&topics-lg=27454|reference+materials&topicsMatch-lg=ANY
# process_file: Error parsing file ../data/csrc.nist.gov/news?sortBy-lg=NewsDateTime+DESC&ipp-lg=25&topics-lg=27454|reference+materials&topicsMatch-lg=ANY.  Skipping
# Skipping unsupported file: ../data/csrc.nist.gov/news?sortBy-lg=NewsDateTime+DESC&ipp-lg=25&topics-lg=27696|audit+&+accountability&topicsMatch-lg=ANY
# process_file: Error parsing file ../data/csrc.nist.gov/news?sortBy-lg=NewsDateTime+DESC&ipp-lg=25&topics-lg=
  Skipping
# Skipping unsupported file: ../data/csrc.nist.gov/News/2023/nist-releases-draft-nist-ir-8460
# process_file: Error parsing file ../data/csrc.nist.gov/News/2023/nist-releases-draft-nist-ir-8460.  Skipping
# Skipping unsupported file: ../data/csrc.nist.gov/News/1999/Request-for-Comments-on-Round-2-AES-Candidates
# process_file: Error parsing file ../data/csrc.nist.gov/News/1999/Request-for-Comments-on-Round-2-AES-Candidates.  Skipping
# Skipping unsupported file: ../data/csrc.nist.gov/News/1999/Announcing-Workshop-on-Key-Management-Using-Public
# process_file: Error parsing file ../data/csrc.nist.gov/News/1999/Announcing-Workshop-on-Key-Management-Using-Public.  Skipping
# Skipping unsupported file: ../data/csrc.nist.gov/News/1999/Request-for-Comments-on-Draft-FIPS-140-2
# process_file: Error parsing file ../data/csrc.nist.gov/News/1999/Request-for-Comments-on-Draft-FIPS-140-2.  Skipping
# Skipping unsupported file: ../data/csrc.nist.gov/News/2012/SECOND-Public-DRAFT-of-NIST-Interagency-Report-762
# process_file: Error parsing file ../data/csrc.nist.gov/News/2012/SECOND-Public-DRAFT-of-NIST-Interagency-Report-762.  Skipping
# Skipping unsupported file: ../data/csrc.nist.gov/News/2012/NIST-Special-Publication-800-38F
# process_file: Error parsing file ../data/csrc.nist.gov/News/2012/NIST-Special-Publication-800-38F.  Skipping
# Skipping unsupported file: ../data/csrc.nist.gov/News/2012/DRAFT-NISTIR-7823,-Advanced-Metering-Infrastructur
# process_file: Error parsing file ../data/csrc.nist.gov/News/2012/DRAFT-NISTIR-7823,-Advanced-Metering-Infrastructur.  Skipping
# Skipping unsupported file: ../data/csrc.nist.gov/News/2000/Approval-of-Withdrawal-of-Thirty-Three-FIPS-Public
# process_file: Error parsing file ../data/csrc.nist.gov/News/2000/Approval-of-Withdrawal-of-Thirty-Three-FIPS-Public.  Skipping
# Skipping unsupported file: ../data/csrc.nist.gov/News/2000/Open-Meeting-of-CSSPAB-(March-2000)
# process_file: Error parsing file ../data/csrc.nist.gov/News/2000/Open-Meeting-of-CSSPAB-(March-2000).  Skipping
# Skipping unsupported file: ../data/csrc.nist.gov/News/2000/Announcing-a-Workshop-on-Modes-of-Operation
# process_file: Error parsing file ../data/csrc.nist.gov/News/2000/Announcing-a-Workshop-on-Modes-of-Operation.  Skipping
# Skipping unsupported file: ../data/csrc.nist.gov/News/2000/Announcing-Approval-of-FIPS-186-2,-Digital-Signatu
# process_file: Error parsing file ../data/csrc.nist.gov/News/2000/Announcing-Approval-of-FIPS-186-2,-Digital-Signatu.  Skipping
# Skipping unsupported file: ../data/csrc.nist.gov/News/2000/Open-Meeting-of-CSSPAB-(June-2000)
# process_file: Error parsing file ../data/csrc.nist.gov/News/2000/Open-Meeting-of-CSSPAB-(June-2000).  Skipping
# Skipping unsupported file: ../data/csrc.nist.gov/News/2013/Draft-SP-800-162,-Guide-to-ABAC-Definition-and-Con
# process_file: Error parsing file ../data/csrc.nist.gov/News/2013/Draft-SP-800-162,-Guide-to-ABAC-Definition-and-Con.  Skipping
# Skipping unsupported file: ../data/csrc.nist.gov/News/2013/Draft-Publication-800-38G
# process_file: Error parsing file ../data/csrc.nist.gov/News/2013/Draft-Publication-800-38G.  Skipping
# Skipping unsupported file: ../data/csrc.nist.gov/News/2013/Public-Comment-NIST-announces-that-Draft-SP-800-1
# process_file: Error parsing file ../data/csrc.nist.gov/News/2013/Public-Comment-NIST-announces-that-Draft-SP-800-1.  Skipping
# Skipping unsupported file: ../data/csrc.nist.gov/News/1993/Revision-of-FIPS-46-1-DES-as-FIPS-46-2
# process_file: Error parsing file ../data/csrc.nist.gov/News/1993/Revision-of-FIPS-46-1-DES-as-FIPS-46-2.  Skipping
# Skipping unsupported file: ../data/csrc.nist.gov/presentations/2019/standards-crypto-2019
# process_file: Error parsing file ../data/csrc.nist.gov/presentations/2019/standards-crypto-2019.  Skipping
# Skipping unsupported file: ../data/csrc.nist.gov/presentations/2019/enter-the-threshold-(the-nist-threshold-cryptograp
# process_file: Error parsing file ../data/csrc.nist.gov/presentations/2019/enter-the-threshold-(the-nist-threshold-cryptograp.  Skipping
# Skipping unsupported file: ../data/csrc.nist.gov/presentations/2022/crclub-2022-11-16
# process_file: Error parsing file ../data/csrc.nist.gov/presentations/2022/crclub-2022-11-16.  Skipping
# Skipping unsupported file: ../data/csrc.nist.gov/presentations/2022/the-first-nist-pqc-standards
# process_file: Error parsing file ../data/csrc.nist.gov/presentations/2022/the-first-nist-pqc-standards.  Skipping
# Skipping unsupported file: ../data/csrc.nist.gov/presentations/2022/crclub-2022-12-14
# process_file: Error parsing file ../data/csrc.nist.gov/presentations/2022/crclub-2022-12-14.  Skipping
# Skipping unsupported file: ../data/csrc.nist.gov/presentations/2022/crclub-2022-10-19
# process_file: Error parsing file ../data/csrc.nist.gov/presentations/2022/crclub-2022-10-19.  Skipping
# Skipping unsupported file: ../data/csrc.nist.gov/presentations/2022/crclub-2022-10-05
# process_file: Error parsing file ../data/csrc.nist.gov/presentations/2022/crclub-2022-10-05.  Skipping
# Skipping unsupported file: ../data/csrc.nist.gov/presentations/2022/crclub-2022-11-02
# process_file: Error parsing file ../data/csrc.nist.gov/presentations/2022/crclub-2022-11-02.  Skipping
# Skipping unsupported file: ../data/csrc.nist.gov/presentations/2004/the-elliptic-curve-digital-signature-algorithm-val
# process_file: Error parsing file ../data/csrc.nist.gov/presentations/2004/the-elliptic-curve-digital-signature-algorithm-val.  Skipping
# Skipping unsupported file: ../data/csrc.nist.gov/presentations/2004/the-rsa-validation-system-(rsavs)
# process_file: Error parsing file ../data/csrc.nist.gov/presentations/2004/the-rsa-validation-system-(rsavs).  Skipping
# Skipping unsupported file: ../data/csrc.nist.gov/presentations/2004/the-digital-signature-algorithm-validation-system
# process_file: Error parsing file ../data/csrc.nist.gov/presentations/2004/the-digital-signature-algorithm-validation-system.  Skipping
# Skipping unsupported file: ../data/csrc.nist.gov/presentations/2018/rmf-2-0-risk-management-framework
# process_file: Error parsing file ../data/csrc.nist.gov/presentations/2018/rmf-2-0-risk-management-framework.  Skipping
# Skipping unsupported file: ../data/csrc.nist.gov/presentations/2015/evaluating-the-capability-and-performance-of-acces
# process_file: Error parsing file ../data/csrc.nist.gov/presentations/2015/evaluating-the-capability-and-performance-of-acces.  Skipping
# Skipping unsupported file: ../data/csrc.nist.gov/presentations/2008/acpt-access-control-policy-tool
# process_file: Error parsing file ../data/csrc.nist.gov/presentations/2008/acpt-access-control-policy-tool.  Skipping
# Skipping unsupported file: ../data/csrc.nist.gov/presentations/2016/15-usc-278g-4-information-security-and-privacy-ad
# process_file: Error parsing file ../data/csrc.nist.gov/presentations/2016/15-usc-278g-4-information-security-and-privacy-ad.  Skipping
# Skipping unsupported file: ../data/csrc.nist.gov/presentations/2021/poster-crypto-sdo
# process_file: Error parsing file ../data/csrc.nist.gov/presentations/2021/poster-crypto-sdo.  Skipping
# Skipping unsupported file: ../data/csrc.nist.gov/presentations/2021/crypto-club-2021-side-channels-2
# process_file: Error parsing file ../data/csrc.nist.gov/presentations/2021/crypto-club-2021-side-channels-2.  Skipping
# Skipping unsupported file: ../data/csrc.nist.gov/presentations/2021/lhe-from-class-groups-of-quadratic-fields
# process_file: Error parsing file ../data/csrc.nist.gov/presentations/2021/lhe-from-class-groups-of-quadratic-fields.  Skipping
# Skipping unsupported file: ../data/csrc.nist.gov/presentations/2021/crypto-club-2021-side-channels-1
# process_file: Error parsing file ../data/csrc.nist.gov/presentations/2021/crypto-club-2021-side-channels-1.  Skipping
# Skipping unsupported file: ../data/csrc.nist.gov/presentations/2020/standards-crypto-2020
# process_file: Error parsing file ../data/csrc.nist.gov/presentations/2020/standards-crypto-2020.  Skipping
# Skipping unsupported file: ../data/csrc.nist.gov/presentations/2023/crclub-2023-01-11
# process_file: Error parsing file ../data/csrc.nist.gov/presentations/2023/crclub-2023-01-11.  Skipping
# Skipping unsupported file: ../data/csrc.nist.gov/schema/piv/chain-of-trust/piv-chain-of-trust-1.0.xsd
# process_file: Error parsing file ../data/csrc.nist.gov/schema/piv/chain-of-trust/piv-chain-of-trust-1.0.xsd.  Skipping
# Skipping unsupported file: ../data/csrc.nist.gov/schema/swid/2015-extensions/swid-2015-extensions-1.0.xsd
# process_file: Error parsing file ../data/csrc.nist.gov/schema/swid/2015-extensions/swid-2015-extensions-1.0.xsd.  Skipping
# Skipping unsupported file: ../data/csrc.nist.gov/csrc/media/Projects/risk-management/images-media/RMF Logos/SVG Format/NIST RMF Graphic.svg
# process_file: Error parsing file ../data/csrc.nist.gov/csrc/media/Projects/risk-management/images-media/RMF Logos/SVG Format/NIST RMF Graphic.svg.  Skipping
# Skipping unsupported file: ../data/csrc.nist.gov/csrc/media/Projects/risk-management/images-media/Stock Images/iStock-submit-pushing-keyboard-with-finger-952729222.jpg
# process_file: Error parsing file ../data/csrc.nist.gov/csrc/media/Projects/risk-management/images-media/Stock Images/iStock-submit-pushing-keyboard-with-finger-952729222.jpg.  Skipping
# process_file: Error parsing file ../data/csrc.nist.gov/csrc/media/Projects/risk-management/800-53 Downloads/800-53Ar4/800-53a-rev4-objectives.csv.  Skipping
# Skipping unsupported file: ../data/csrc.nist.gov/csrc/media/Projects/risk-management/800-53 Downloads/800-53r5/docs_deliverables_800-53_XML_Template_Rev5 (1).xsl
# process_file: Error parsing file ../data/csrc.nist.gov/csrc/media/Projects/risk-management/800-53 Downloads/800-53r5/docs_deliverables_800-53_XML_Template_Rev5 (1).xsl.  Skipping
# Skipping unsupported file: ../data/csrc.nist.gov/csrc/media/Projects/risk-management/800-53 Downloads/800-53r5/NIST SP 800-53B-Jan2022.xlsx
# process_file: Error parsing file ../data/csrc.nist.gov/csrc/media/Projects/risk-management/800-53 Downloads/800-53r5/NIST SP 800-53B-Jan2022.xlsx.  Skipping
# process_file: Error parsing file ../data/csrc.nist.gov/csrc/media/Projects/risk-management/800-53 Downloads/800-53r4/800-53-rev4-controls.csv.  Skipping
# Skipping unsupported file: ../data/csrc.nist.gov/csrc/media/Projects/risk-management/800-53 Downloads/800-53Ar5/sp800-53ar5-assessment-procedures.xlsx
# process_file: Error parsing file ../data/csrc.nist.gov/csrc/media/Projects/risk-management/800-53 Downloads/800-53Ar5/sp800-53ar5-assessment-procedures.xlsx.  Skipping
# process_file: Error parsing file ../data/csrc.nist.gov/csrc/media/Projects/risk-management/documents/Additional Resources/NIST RMF Roles and Responsibilities Crosswalk.pdf.  Skipping
# Found 1 parts in file ../data/csrc.nist.gov/csrc/media/Projects/risk-management/800-53 Comment Site/SP800-53_Comment_Site_Infographic.pdf
# Skipping unsupported file: ../data/csrc.nist.gov/csrc/media/Projects/risk-management/800-53 Comment Site/download-icon.svg
# process_file: Error parsing file ../data/csrc.nist.gov/csrc/media/Projects/risk-management/800-53 Comment Site/download-icon.svg.  Skipping
# Skipping unsupported file: ../data/csrc.nist.gov/csrc/media/Projects/risk-management/800-53 Comment Site/SP800-53_Comment_Site_Infographic.jpeg
# process_file: Error parsing file ../data/csrc.nist.gov/csrc/media/Projects/risk-management/800-53 Comment Site/SP800-53_Comment_Site_Infographic.jpeg.  Skipping
# Skipping unsupported file: ../data/csrc.nist.gov/csrc/media/Projects/risk-management/800-53 Comment Site/overlay_repo_icon.svg
# process_file: Error parsing file ../data/csrc.nist.gov/csrc/media/Projects/risk-management/800-53 Comment Site/overlay_repo_icon.svg.  Skipping
# Skipping unsupported file: ../data/csrc.nist.gov/csrc/media/Projects/risk-management/800-53 Comment Site/search_icon.svg
# process_file: Error parsing file ../data/csrc.nist.gov/csrc/media/Projects/risk-management/800-53 Comment Site/search_icon.svg.  Skipping
